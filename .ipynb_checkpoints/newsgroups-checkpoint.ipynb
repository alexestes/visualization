# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import operator

from wordcloud import WordCloud
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.feature_extraction import text

import spacy
nlp = spacy.load("en_core_web_lg")

import string
punctuation = string.punctuation

# %matplotlib inline

# %% [markdown]
# ## install spacy
#
# ### bash
#
# `pip install spacy`
#
# `python -m spacy download en`
#
# `python -m spacy download en_core_web_lg`
#
# ### python
#
# `import spacy`
#
# `nlp = spacy.load("en")`
#
# `nlp = spacy.load("en_core_web_lg")`

# %%
# load data
data = fetch_20newsgroups(subset='train')

# make dataframe
df = pd.DataFrame(data.data)

# add targets
df['target'] = data.target

# rename text column
df.rename(columns={0:'text'}, inplace=True)

# add label names
target_names = data.target_names
df['label'] = df['target'].apply(lambda x: target_names[x])

# %%
df = df[(df['label'] == 'rec.autos') | (df['label'] == 'sci.med') | (df['label'] == 'rec.sport.baseball')]

# %%
df['label'].unique()
# Out:
# array(['rec.autos', 'sci.med', 'rec.sport.baseball'], dtype=object)

# %% [markdown]
# ### at this stage the df has 'text', 'target', and 'label' columns. the rest should be able to be done to any df provided it has these columns

# %% [markdown]
# ## preprocessing
#
# add to built in stopwords
#
# lemmatization would be very helpful

# %%
# make spacy docs

df['spacy'] = df['text'].apply(nlp)

# %%
# custom stop words based off of sklearn
my_stop_words = text.ENGLISH_STOP_WORDS.union({"edu",
                                               "ca",
                                               "com",
                                               "gov",
                                               "university",
                                               "posting",
                                               "line",
                                               "lines",
                                               "host",
                                               "nntp",
                                               "write",
                                               "subject",
                                               "organization",
                                               "article",
                                               "like",
                                               "think",
                                               "know",
                                               "do",
                                               "just",
                                               "use",
                                               "say",
                                               "from"
                                                })

# %%
# lemmatize and filter out stop words
def lemmatize(spacy_doc):
    
    lemmata = []
    
    for tok in spacy_doc:
        if not tok.is_punct and tok.text not in punctuation and "\n" not in tok.text:
            if tok.lemma_ not in my_stop_words:
                lemmata.append(tok.lemma_)
            
    return " ".join(lemmata)

df['lemmatized'] = df['spacy'].apply(lemmatize)

# %% [markdown]
# ## clustering

# %%
count_vect = CountVectorizer(stop_words=my_stop_words,
                            ngram_range = (2,4)
                            )

tfidf_transformer = TfidfTransformer()

counts = count_vect.fit_transform(df['lemmatized'])
tfidf = tfidf_transformer.fit_transform(counts)

# %%
from sklearn.cluster import KMeans

num_clusters = 3

km = KMeans(n_clusters=num_clusters)

km.fit(tfidf)

clusters = km.labels_.tolist()

# %%
df['cluster'] = clusters

# %%
df['label'].unique()

# %%
for label in df['label'].unique():
    print(label)
    print(df[df['label'] == label].cluster.value_counts())
    print()

# %% [markdown]
# ## classification

# %%
# create X (features) and y (targets)

X = df['lemmatized']
y = df['target']

# %% [markdown]
# ## bernoulli naive bayes classifier
# used for binary features, i.e., word's occurrence in a document, _not_ its count

# %%
# create vectorizer with stop words, optional to add ngrams

count_vect = CountVectorizer(stop_words=my_stop_words, #stop_words='english'
                            #ngram_range = (1,1)
                            )

# no tfidf because bernoulli does binary, tfidf relies on counts

# %%
# create count vectors
counts = count_vect.fit_transform(X)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(counts, y, test_size=.25)

# %%
# fit model
bern_clf = BernoulliNB().fit(X_train, y_train) # use binary occurrence for bernoulli

# %%
# get score on test data

bern_clf.score(X_test, y_test)
# Out:
# 0.93288590604026844

# %%
# get top 10 features for each class and their weights
# weights are log probabilities, which are negative since log of everything in the interval (0,1) is negative

def get_top_10_features(vectorizer, clf, class_labels, class_names):
    
    top10_features = {}
    
    feature_names = vectorizer.get_feature_names()
    
    for i, class_label in enumerate(class_labels):
        
        name = class_names[i]
        
        top10_weights = sorted(clf.coef_[i])[-10:]
        top10_indices = np.argsort(clf.coef_[i])[-10:]
        top10_names = [feature_names[j] for j in top10_indices]
        
        top10_features[name] = {n:w for n,w in zip(top10_names, top10_weights)}
        
    return top10_features
        
top10 = get_top_10_features(count_vect, # vectorizer
                            bern_clf, # classifier
                            bern_clf.classes_, # classes (as ints)
                            ['autos', 'baseball', 'medicine']) # labels (as strs)

# %%
# print out features

for k,v in top10.items():
    print(k)
    features = list(sorted(v.items(), key=operator.itemgetter(1)))[::-1]
    for k,v in features:
        print(k, v)
    print()
# Out:
# autos
# pron -0.0309759278943
# car -0.402202462473
# good -0.897941593206
# distribution -1.10516968921
# time -1.21639532432
# make -1.24624828747
# usa -1.30876864446
# drive -1.32502916533
# look -1.34992671695
# new -1.36687627526
#
# baseball
# pron -0.0467374778517
# game -0.982352482552
# year -0.982352482552
# good -0.994622575144
# baseball -1.08500663661
# team -1.14774497725
# run -1.24593700342
# win -1.32004497558
# time -1.34602046198
# make -1.36372003908
#
# medicine
# pron -0.0180591815384
# reply -1.0656059922
# good -1.18257766879
# time -1.20471879466
# cs -1.21975667203
# people -1.23502414416
# make -1.26627668766
# science -1.31506685183
# problem -1.40207822882
# year -1.42042736749

# %% [markdown]
# ## multinomial naive bayes classifier
# used for word counts in each document, not simply occurrence

# %%
count_vect = CountVectorizer(stop_words=my_stop_words,
                            #ngram_range = (1,2)
                            )
tfidf_transformer = TfidfTransformer()

# %%
counts = count_vect.fit_transform(X)
tfidf = tfidf_transformer.fit_transform(counts)

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf, y, test_size=.25)

# %%
mn_clf = MultinomialNB().fit(X_train, y_train) # use word counts for multinomial

# %%
mn_clf.score(X_test, y_test)
# Out:
# 0.98657718120805371

# %%
top10 = get_top_10_features(count_vect, # vectorizer
                            mn_clf, # classifier
                            mn_clf.classes_, # classes (as ints)
                            ['autos', 'baseball', 'medicine']) # labels (as strs)

# print out features

for k,v in top10.items():
    print(k)
    features = list(sorted(v.items(), key=operator.itemgetter(1)))[::-1]
    for k,v in features:
        print(k, v)
    print()
# Out:
# autos
# pron -5.75662080798
# car -6.87435770274
# good -8.05987572745
# drive -8.06592907587
# buy -8.10031082035
# engine -8.10059426516
# new -8.16318083333
# dealer -8.20871290549
# price -8.25178808149
# look -8.26372769725
#
# baseball
# pron -5.92879189658
# game -7.35258755245
# team -7.65784558011
# baseball -7.69314761749
# year -7.70046767909
# win -7.72391867937
# good -7.84572015473
# run -7.84716414159
# player -7.85537365379
# hit -7.96854420743
#
# medicine
# pron -5.81309650127
# pitt -7.58317512843
# msg -7.70039077665
# gordon -7.73384501141
# banks -7.74149885353
# geb -7.74219905079
# food -7.85994123099
# cs -7.90614094058
# science -8.01905043978
# doctor -8.07101189706

# %% [markdown]
# ## old print top 10

# %%
def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        print(data.target_names[i])
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (class_label,
              ", ".join(feature_names[j] for j in top10)))
        print()

print_top10(count_vect, bern_clf, bern_clf.classes_)

# %% [markdown]
# # ngrams visualization

# %%
bb = df[df['label'] == "rec.sport.baseball"]

# %%
# make spacy docs

bb['spacy'] = bb['text'].apply(nlp)

# %%
# preprocess/clean docs

def preprocess(spacy_doc):
    '''
    This function takes a spacy doc and filters out tokens that are punctuation, determiners, pronouns, numbers, etc.
    It filters out stop words and returns the lemma of each remaining word.
    The lemmata are rejoined to form a string.
    '''
    
    cleaned = []
    
    bad_pos = ['PUNCT',
              'SYM',
              'X',
              'NIL',
              'PRON',
              'SPACE',
              'DET',
              'NUM',
              'PROPN']
    
    for token in spacy_doc:
        if token.text not in punctuation:
            if token.pos_ not in bad_pos:
                if token.text not in my_stop_words and token.lemma_ not in my_stop_words:
                    cleaned.append(token.lemma_)
                
    return " ".join(cleaned)

bb['cleaned'] = bb['spacy'].apply(preprocess)
# Out:
# /Users/alex/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# get bigrams and trigrams

def find_bigrams(s):
    
    words = s.split()
    
    return list(zip(words, words[1:]))


def find_trigrams(s):
    
    words = s.split()
    
    return list(zip(words, words[1:], words[2:]))

# clever way to do ngrams
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))

bb['bigrams'] = bb['cleaned'].apply(find_bigrams)
bb['trigrams'] = bb['cleaned'].apply(find_trigrams)
# Out:
# /Users/alex/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/alex/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# create lists of all bigrams and trigrams in the collection

bigrams = []
for b in bb['bigrams']:
    bigrams.extend(b)
    
trigrams = []
for t in bb['trigrams']:
    trigrams.extend(t)

# %%
# get bigram and trigram counts

bigram_counts = {}

for b in bigrams:
    if b not in bigram_counts:
        bigram_counts[b] = 1
    else:
        bigram_counts[b] += 1
        
trigram_counts = {}

for t in trigrams:
    if t not in trigram_counts:
        trigram_counts[t] = 1
    else:
        trigram_counts[t] += 1

# %%
# sort bigrams and trigrams to get most frequent

sorted_bigrams = sorted(bigram_counts.items(), key=operator.itemgetter(1))[::-1]
sorted_trigrams = sorted(trigram_counts.items(), key=operator.itemgetter(1))[::-1]

# %%
# word cloud of most frequent bigrams

bigrams_string = ""

for b in sorted_bigrams[:200]:
    bigrams_string += b[0][0] + "_" + b[0][1] +  " "
    
wordcloud = WordCloud(max_font_size=80).generate(bigrams_string)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# word cloud of most frequent trigrams

trigrams_string = ""

for t in sorted_trigrams[:200]:
    trigrams_string += t[0][0] + "_" + t[0][1] +  "_" + t[0][2] + " "
    
wordcloud = WordCloud(max_font_size=80).generate(trigrams_string)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # other linguistic patterns

# %% [markdown]
# ## named entities

# %%
df['spacy'] = df['text'].apply(nlp)

# %%
df['entities'] = df['spacy'].apply(lambda x: [{'entity': e.text,
                                               'label': e.label_}
                                               for e in  x.ents])

# %%
entities = []

for e in df['entities']:
    entities.extend(e)

# %%
excluded_strings = ["\n\n", "\n", "\n \n", '  ', '\n|', '|', '  |', '\nOrganization', '\nOrganization:']
excluded_labels = ["CARDINAL", "PERCENT", "DATE", "MONEY"]

entities = [x for x in entities if x['entity'] not in excluded_strings]
entities = [x for x in entities if x['label'] not in excluded_labels]

# %%
entity_counts = {}

for e in entities:
    if e['entity'] not in entity_counts:
        entity_counts[e['entity']] = 1
        
    else:
        entity_counts[e['entity']] += 1

# %%
sorted_entities = sorted(entity_counts.items(), key=operator.itemgetter(1))[::-1]

# %%
# word cloud of most frequent bigrams

ent_string = ""

for e in sorted_entities[:100]:
    ent_string += e[0] + " "
    
wordcloud = WordCloud(max_font_size=100).generate(ent_string)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## noun chunks
#
# also plotting frequencies
#
# things to try:
#
# -classification based on noun chunks
#
# -plotting tf-idf values of noun chunks

# %%
df['chunks'] = df['spacy'].apply(lambda x: [c.text for c in x.noun_chunks])

# %%
chunks = []

for c in df['chunks']:
    chunks.extend(c)

# %%
chunk_counts = {}

for c in chunks:
    if c not in chunk_counts:
        chunk_counts[c] = 1
    else:
        chunk_counts[c] += 1

# %%
sorted_chunks = sorted(chunk_counts.items(), key=operator.itemgetter(1))[::-1]

# %%
# word cloud of most frequent bigrams

chunk_string = ""

for e in sorted_chunks[50:250]:
    chunk_string += e[0].replace(" ", "_") + " "
    
wordcloud = WordCloud(max_font_size=100).generate(chunk_string)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
series = pd.Series([c[1] for c in sorted_chunks[20:40]], index = [c[0] for c in sorted_chunks[20:40]])

# %%
series.plot(kind='bar')

# %% [markdown]
# clearly pronouns and such need to be filtered out to get interesting stuff!
